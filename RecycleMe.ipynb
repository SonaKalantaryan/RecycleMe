# %%
#train images
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-139ccd5f-e59e-4b65-aad5-f0a190a2cd1b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-139ccd5f-e59e-4b65-aad5-f0a190a2cd1b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#test images
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-91570fcb-4184-463f-a1c2-463c55132aa9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-91570fcb-4184-463f-a1c2-463c55132aa9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os

# %%
os.makedirs('/content/images/glass', exist_ok=True)
os.makedirs('/content/images/carton', exist_ok=True)
os.makedirs('/content/images/metallic', exist_ok=True)
os.makedirs('/content/images/plastic', exist_ok=True)

# %%
os.makedirs('/content/test_images', exist_ok=True)

# %%
os.makedirs('/content/test_images/glass', exist_ok=True)
os.makedirs('/content/test_images/carton', exist_ok=True)
os.makedirs('/content/test_images/metallic', exist_ok=True)
os.makedirs('/content/test_images/plastic', exist_ok=True)

# %%
os.listdir('/content/')
# Out:
# ['.config',
#  'metallic2 (1).png',
#  'carton2 (1).png',
#  'plastic5.png',
#  'metallic5.png',
#  'carton3 (2).png',
#  'carton1 (1).png',
#  'plastic3 (1).png',
#  'metallic1.png',
#  'carton4.png',
#  'carton5 (1).png',
#  'plastic7 (1).png',
#  'carton2.png',
#  'metallic2 (2).png',
#  'carton7 (1).png',
#  'carton1.png',
#  'plastic2 (1).png',
#  'metallic3 (2).png',
#  'mobilenet_v2_tuned.keras',
#  'glass2 (1).png',
#  'metallic4.png',
#  'test_images',
#  'plastic4.png',
#  'glass6 (1).png',
#  'glass3 (2).png',
#  'plastic2.png',
#  'plastic1 (1).png',
#  'plastic6 (1).png',
#  'metallic1 (1).png',
#  'metallic7 (1).png',
#  'metallic3 (1).png',
#  'plastic1 (2).png',
#  'plastic3.png',
#  'glass3 (1).png',
#  'metallic6 (1).png',
#  'glass7 (1).png',
#  'glass4 (1).png',
#  'glass1 (1).png',
#  'glass5.png',
#  'Screenshot 2024-12-10 at 04.03.53.png',
#  'images',
#  'carton6 (1).png',
#  'sample_data']

# %%
# train images
import shutil

shutil.move('/content/glass1.jpg', '/content/images/glass/glass1.jpg')
shutil.move('/content/glass2.jpeg', '/content/images/glass/glass2.jpeg')
shutil.move('/content/glass3.png', '/content/images/glass/glass3.png')
shutil.move('/content/glass4.png', '/content/images/glass/glass4.png')
shutil.move('/content/glass5.jpg', '/content/images/glass/glass5.jpg')
shutil.move('/content/glass6.png', '/content/images/glass/glass6.png')
shutil.move('/content/glass7.png', '/content/images/glass/glass7.png')
shutil.move('/content/glass8.png', '/content/images/glass/glass8.png')
shutil.move('/content/glass9.png', '/content/images/glass/glass9.png')
shutil.move('/content/glass10.png', '/content/images/glass/glass10.png')
shutil.move('/content/glass11.png', '/content/images/glass/glass11.png')
shutil.move('/content/glass12.png', '/content/images/glass/glass12.png')
shutil.move('/content/glass13.png', '/content/images/glass/glass13.png')
shutil.move('/content/glass14.png', '/content/images/glass/glass14.png')
shutil.move('/content/glass15.png', '/content/images/glass/glass15.png')
shutil.move('/content/glass16.png', '/content/images/glass/glass16.png')
shutil.move('/content/glass17.png', '/content/images/glass/glass17.png')
shutil.move('/content/glass18.png', '/content/images/glass/glass18.png')
shutil.move('/content/glass19.png', '/content/images/glass/glass19.png')
shutil.move('/content/glass20.png', '/content/images/glass/glass20.png')
shutil.move('/content/glass21.png', '/content/images/glass/glass21.png')
shutil.move('/content/glass22.png', '/content/images/glass/glass22.png')
shutil.move('/content/glass23.png', '/content/images/glass/glass23.png')
shutil.move('/content/glass24.png', '/content/images/glass/glass24.png')
shutil.move('/content/glass25.png', '/content/images/glass/glass25.png')
shutil.move('/content/glass26.png', '/content/images/glass/glass26.png')
shutil.move('/content/glass27.png', '/content/images/glass/glass27.png')
shutil.move('/content/glass28.png', '/content/images/glass/glass28.png')
shutil.move('/content/glass29.png', '/content/images/glass/glass29.png')
shutil.move('/content/glass30.png', '/content/images/glass/glass30.png')
shutil.move('/content/glass31.png', '/content/images/glass/glass31.png')
shutil.move('/content/glass32.png', '/content/images/glass/glass32.png')
shutil.move('/content/glass33.png', '/content/images/glass/glass33.png')
shutil.move('/content/glass34.png', '/content/images/glass/glass34.png')
shutil.move('/content/glass35.png', '/content/images/glass/glass35.png')
shutil.move('/content/glass36.png', '/content/images/glass/glass36.png')
shutil.move('/content/glass37.png', '/content/images/glass/glass37.png')
shutil.move('/content/glass38.png', '/content/images/glass/glass38.png')
shutil.move('/content/glass39.png', '/content/images/glass/glass39.png')
shutil.move('/content/glass40.png', '/content/images/glass/glass40.png')
shutil.move('/content/glass41.png', '/content/images/glass/glass41.png')
shutil.move('/content/glass42.png', '/content/images/glass/glass42.png')
shutil.move('/content/glass43.png', '/content/images/glass/glass43.png')
shutil.move('/content/glass44.png', '/content/images/glass/glass44.png')
shutil.move('/content/glass45.png', '/content/images/glass/glass45.png')
shutil.move('/content/glass46.png', '/content/images/glass/glass46.png')
shutil.move('/content/glass47.png', '/content/images/glass/glass47.png')
shutil.move('/content/glass48.png', '/content/images/glass/glass48.png')
shutil.move('/content/glass49.png', '/content/images/glass/glass49.png')
shutil.move('/content/glass50.png', '/content/images/glass/glass50.png')
shutil.move('/content/glass51.png', '/content/images/glass/glass51.png')
shutil.move('/content/glass52.png', '/content/images/glass/glass52.png')
shutil.move('/content/glass53.png', '/content/images/glass/glass53.png')
shutil.move('/content/glass54.png', '/content/images/glass/glass54.png')
shutil.move('/content/glass55.png', '/content/images/glass/glass55.png')
shutil.move('/content/glass56.png', '/content/images/glass/glass56.png')

shutil.move('/content/carton1.jpg', '/content/images/carton/carton1.jpg')
shutil.move('/content/carton2.jpg', '/content/images/carton/carton2.jpg')
shutil.move('/content/carton3.png', '/content/images/carton/carton3.png')
shutil.move('/content/carton4.jpeg', '/content/images/carton/carton4.jpeg')
shutil.move('/content/carton5.png', '/content/images/carton/carton5.png')
shutil.move('/content/carton6.png', '/content/images/carton/carton6.png')
shutil.move('/content/carton7.png', '/content/images/carton/carton7.png')
shutil.move('/content/carton8.png', '/content/images/carton/carton8.png')
shutil.move('/content/carton9.png', '/content/images/carton/carton9.png')
shutil.move('/content/carton10.png', '/content/images/carton/carton10.png')
shutil.move('/content/carton11.png', '/content/images/carton/carton11.png')
shutil.move('/content/carton12.png', '/content/images/carton/carton12.png')
shutil.move('/content/carton13.png', '/content/images/carton/carton13.png')
shutil.move('/content/carton14.png', '/content/images/carton/carton14.png')
shutil.move('/content/carton15.png', '/content/images/carton/carton15.png')
shutil.move('/content/carton16.png', '/content/images/carton/carton16.png')
shutil.move('/content/carton17.png', '/content/images/carton/carton17.png')
shutil.move('/content/carton18.png', '/content/images/carton/carton18.png')
shutil.move('/content/carton19.png', '/content/images/carton/carton19.png')
shutil.move('/content/carton20.png', '/content/images/carton/carton20.png')
shutil.move('/content/carton21.png', '/content/images/carton/carton21.png')
shutil.move('/content/carton22.png', '/content/images/carton/carton22.png')
shutil.move('/content/carton23.png', '/content/images/carton/carton23.png')
shutil.move('/content/carton24.png', '/content/images/carton/carton24.png')
shutil.move('/content/carton25.png', '/content/images/carton/carton25.png')
shutil.move('/content/carton26.png', '/content/images/carton/carton26.png')
shutil.move('/content/carton27.png', '/content/images/carton/carton27.png')
shutil.move('/content/carton28.png', '/content/images/carton/carton28.png')
shutil.move('/content/carton29.png', '/content/images/carton/carton29.png')
shutil.move('/content/carton30.png', '/content/images/carton/carton30.png')
shutil.move('/content/carton31.png', '/content/images/carton/carton31.png')
shutil.move('/content/carton32.png', '/content/images/carton/carton32.png')
shutil.move('/content/carton33.png', '/content/images/carton/carton33.png')
shutil.move('/content/carton34.png', '/content/images/carton/carton34.png')
shutil.move('/content/carton35.png', '/content/images/carton/carton35.png')
shutil.move('/content/carton36.png', '/content/images/carton/carton36.png')
shutil.move('/content/carton37.png', '/content/images/carton/carton37.png')
shutil.move('/content/carton38.png', '/content/images/carton/carton38.png')
shutil.move('/content/carton39.png', '/content/images/carton/carton39.png')
shutil.move('/content/carton40.png', '/content/images/carton/carton40.png')
shutil.move('/content/carton41.png', '/content/images/carton/carton41.png')
shutil.move('/content/carton42.png', '/content/images/carton/carton42.png')
shutil.move('/content/carton43.png', '/content/images/carton/carton43.png')
shutil.move('/content/carton44.png', '/content/images/carton/carton44.png')
shutil.move('/content/carton45.png', '/content/images/carton/carton45.png')
shutil.move('/content/carton46.png', '/content/images/carton/carton46.png')
shutil.move('/content/carton47.png', '/content/images/carton/carton47.png')
shutil.move('/content/carton48.png', '/content/images/carton/carton48.png')
shutil.move('/content/carton49.png', '/content/images/carton/carton49.png')
shutil.move('/content/carton50.png', '/content/images/carton/carton50.png')
shutil.move('/content/carton51.png', '/content/images/carton/carton51.png')
shutil.move('/content/carton52.png', '/content/images/carton/carton52.png')
shutil.move('/content/carton53.png', '/content/images/carton/carton53.png')
shutil.move('/content/carton54.png', '/content/images/carton/carton54.png')
shutil.move('/content/carton55.png', '/content/images/carton/carton55.png')
shutil.move('/content/carton56.png', '/content/images/carton/carton56.png')
shutil.move('/content/carton57.png', '/content/images/carton/carton57.png')
shutil.move('/content/carton58.png', '/content/images/carton/carton58.png')
shutil.move('/content/carton59.png', '/content/images/carton/carton59.png')
shutil.move('/content/carton60.png', '/content/images/carton/carton60.png')

shutil.move('/content/metallic2.png', '/content/images/metallic/metallic2.png')
shutil.move('/content/metallic2.jpeg', '/content/images/metallic/metallic2.jpeg')
shutil.move('/content/metallic3.png', '/content/images/metallic/metallic3.png')
shutil.move('/content/metallic4.jpeg', '/content/images/metallic/metallic4.jpeg')
shutil.move('/content/metallic5.jpg', '/content/images/metallic/metallic5.jpg')
shutil.move('/content/metallic6.png', '/content/images/metallic/metallic6.png')
shutil.move('/content/metallic7.png', '/content/images/metallic/metallic7.png')
shutil.move('/content/metallic8.png', '/content/images/metallic/metallic8.png')
shutil.move('/content/metallic9.png', '/content/images/metallic/metallic9.png')
shutil.move('/content/metallic10.png', '/content/images/metallic/metallic10.png')
shutil.move('/content/metallic11.png', '/content/images/metallic/metallic11.png')
shutil.move('/content/metallic12.png', '/content/images/metallic/metallic12.png')
shutil.move('/content/metallic13.png', '/content/images/metallic/metallic13.png')
shutil.move('/content/metallic14.png', '/content/images/metallic/metallic14.png')
shutil.move('/content/metallic15.png', '/content/images/metallic/metallic15.png')
shutil.move('/content/metallic16.png', '/content/images/metallic/metallic16.png')
shutil.move('/content/metallic17.png', '/content/images/metallic/metallic17.png')
shutil.move('/content/metallic18.png', '/content/images/metallic/metallic18.png')
shutil.move('/content/metallic19.png', '/content/images/metallic/metallic19.png')
shutil.move('/content/metallic20.png', '/content/images/metallic/metallic20.png')
shutil.move('/content/metallic21.png', '/content/images/metallic/metallic21.png')
shutil.move('/content/metallic22.png', '/content/images/metallic/metallic22.png')
shutil.move('/content/metallic23.png', '/content/images/metallic/metallic23.png')
shutil.move('/content/metallic24.png', '/content/images/metallic/metallic24.png')
shutil.move('/content/metallic25.png', '/content/images/metallic/metallic25.png')
shutil.move('/content/metallic26.png', '/content/images/metallic/metallic26.png')
shutil.move('/content/metallic27.png', '/content/images/metallic/metallic27.png')
shutil.move('/content/metallic28.png', '/content/images/metallic/metallic28.png')
shutil.move('/content/metallic29.png', '/content/images/metallic/metallic29.png')
shutil.move('/content/metallic30.png', '/content/images/metallic/metallic30.png')
shutil.move('/content/metallic31.png', '/content/images/metallic/metallic31.png')
shutil.move('/content/metallic32.png', '/content/images/metallic/metallic32.png')
shutil.move('/content/metallic33.png', '/content/images/metallic/metallic33.png')
shutil.move('/content/metallic34.png', '/content/images/metallic/metallic34.png')
shutil.move('/content/metallic35.png', '/content/images/metallic/metallic35.png')
shutil.move('/content/metallic36.png', '/content/images/metallic/metallic36.png')
shutil.move('/content/metallic37.png', '/content/images/metallic/metallic37.png')
shutil.move('/content/metallic38.png', '/content/images/metallic/metallic38.png')
shutil.move('/content/metallic39.png', '/content/images/metallic/metallic39.png')
shutil.move('/content/metallic40.png', '/content/images/metallic/metallic40.png')
shutil.move('/content/metallic41.png', '/content/images/metallic/metallic41.png')
shutil.move('/content/metallic42.png', '/content/images/metallic/metallic42.png')
shutil.move('/content/metallic43.png', '/content/images/metallic/metallic43.png')
shutil.move('/content/metallic44.png', '/content/images/metallic/metallic44.png')
shutil.move('/content/metallic45.png', '/content/images/metallic/metallic45.png')
shutil.move('/content/metallic46.png', '/content/images/metallic/metallic46.png')
shutil.move('/content/metallic47.png', '/content/images/metallic/metallic47.png')
shutil.move('/content/metallic48.png', '/content/images/metallic/metallic48.png')
shutil.move('/content/metallic49.png', '/content/images/metallic/metallic49.png')
shutil.move('/content/metallic50.png', '/content/images/metallic/metallic50.png')
shutil.move('/content/metallic51.png', '/content/images/metallic/metallic51.png')
shutil.move('/content/metallic52.png', '/content/images/metallic/metallic52.png')
shutil.move('/content/metallic53.png', '/content/images/metallic/metallic53.png')
shutil.move('/content/metallic54.png', '/content/images/metallic/metallic54.png')
shutil.move('/content/metallic55.png', '/content/images/metallic/metallic55.png')


shutil.move('/content/plastic1.png', '/content/images/plastic/plastic1.png')
shutil.move('/content/Plastic2.jpg', '/content/images/plastic/Plastic2.jpg')
shutil.move('/content/plastic3.jpeg', '/content/images/plastic/plastic3.jpeg')
shutil.move('/content/plastic4.jpeg', '/content/images/plastic/plastic4.jpeg')
shutil.move('/content/plastic5.jpeg', '/content/images/plastic/plastic5.jpeg')
shutil.move('/content/plastic6.png', '/content/images/plastic/plastic6.png')
shutil.move('/content/plastic7.png', '/content/images/plastic/plastic7.png')
shutil.move('/content/plastic8.png', '/content/images/plastic/plastic8.png')
shutil.move('/content/plastic9.png', '/content/images/plastic/plastic9.png')
shutil.move('/content/plastic10.png', '/content/images/plastic/plastic10.png')
shutil.move('/content/plastic11.png', '/content/images/plastic/plastic11.png')
shutil.move('/content/plastic12.png', '/content/images/plastic/plastic12.png')
shutil.move('/content/plastic13.png', '/content/images/plastic/plastic13.png')
shutil.move('/content/plastic14.png', '/content/images/plastic/plastic14.png')
shutil.move('/content/plastic15.png', '/content/images/plastic/plastic15.png')
shutil.move('/content/plastic16.png', '/content/images/plastic/plastic16.png')
shutil.move('/content/plastic17.png', '/content/images/plastic/plastic17.png')
shutil.move('/content/plastic18.png', '/content/images/plastic/plastic18.png')
shutil.move('/content/plastic19.png', '/content/images/plastic/plastic19.png')
shutil.move('/content/plastic20.png', '/content/images/plastic/plastic20.png')
shutil.move('/content/plastic21.png', '/content/images/plastic/plastic21.png')
shutil.move('/content/plastic22.png', '/content/images/plastic/plastic22.png')
shutil.move('/content/plastic23.png', '/content/images/plastic/plastic23.png')
shutil.move('/content/plastic24.png', '/content/images/plastic/plastic24.png')
shutil.move('/content/plastic25.png', '/content/images/plastic/plastic25.png')
shutil.move('/content/plastic26.png', '/content/images/plastic/plastic26.png')
shutil.move('/content/plastic27.png', '/content/images/plastic/plastic27.png')
shutil.move('/content/plastic28.png', '/content/images/plastic/plastic28.png')
shutil.move('/content/plastic29.png', '/content/images/plastic/plastic29.png')
shutil.move('/content/plastic30.png', '/content/images/plastic/plastic30.png')
shutil.move('/content/plastic31.png', '/content/images/plastic/plastic31.png')
shutil.move('/content/plastic32.png', '/content/images/plastic/plastic32.png')
shutil.move('/content/plastic33.png', '/content/images/plastic/plastic33.png')
shutil.move('/content/plastic34.png', '/content/images/plastic/plastic34.png')
shutil.move('/content/plastic35.png', '/content/images/plastic/plastic35.png')
shutil.move('/content/plastic36.png', '/content/images/plastic/plastic36.png')
shutil.move('/content/plastic37.png', '/content/images/plastic/plastic37.png')
shutil.move('/content/plastic38.png', '/content/images/plastic/plastic38.png')
shutil.move('/content/plastic39.png', '/content/images/plastic/plastic39.png')
shutil.move('/content/plastic40.png', '/content/images/plastic/plastic40.png')
shutil.move('/content/plastic41.png', '/content/images/plastic/plastic41.png')
shutil.move('/content/plastic42.png', '/content/images/plastic/plastic42.png')
shutil.move('/content/plastic43.png', '/content/images/plastic/plastic43.png')
shutil.move('/content/plastic44.png', '/content/images/plastic/plastic44.png')
shutil.move('/content/plastic45.png', '/content/images/plastic/plastic45.png')
shutil.move('/content/plastic46.png', '/content/images/plastic/plastic46.png')
shutil.move('/content/plastic47.png', '/content/images/plastic/plastic47.png')
shutil.move('/content/plastic48.png', '/content/images/plastic/plastic48.png')
shutil.move('/content/plastic49.png', '/content/images/plastic/plastic49.png')
shutil.move('/content/plastic50.png', '/content/images/plastic/plastic50.png')
shutil.move('/content/plastic51.png', '/content/images/plastic/plastic51.png')
shutil.move('/content/plastic52.png', '/content/images/plastic/plastic52.png')
shutil.move('/content/plastic53.png', '/content/images/plastic/plastic53.png')
shutil.move('/content/plastic54.png', '/content/images/plastic/plastic54.png')
shutil.move('/content/plastic55.png', '/content/images/plastic/plastic55.png')
# Out:
# '/content/images/plastic/plastic55.png'

# %%
#test images
import shutil

shutil.move('/content/glass1.png', '/content/test_images/glass/glass1.png')
shutil.move('/content/glass2.png', '/content/test_images/glass/glass2.png')
shutil.move('/content/glass3.png', '/content/test_images/glass/glass3.png')
shutil.move('/content/glass4.png', '/content/test_images/glass/glass4.png')
shutil.move('/content/glass5.png', '/content/test_images/glass/glass5.png')
shutil.move('/content/glass6.png', '/content/test_images/glass/glass6.png')
shutil.move('/content/glass7.png', '/content/test_images/glass/glass7.png')

shutil.move('/content/plastic1.png', '/content/test_images/plastic/plastic1.png')
shutil.move('/content/plastic2.png', '/content/test_images/plastic/plastic2.png')
shutil.move('/content/plastic3.png', '/content/test_images/plastic/plastic3.png')
shutil.move('/content/plastic4.png', '/content/test_images/plastic/plastic4.png')
shutil.move('/content/plastic5.png', '/content/test_images/plastic/plastic5.png')
shutil.move('/content/plastic6.png', '/content/test_images/plastic/plastic6.png')
shutil.move('/content/plastic7.png', '/content/test_images/plastic/plastic7.png')

shutil.move('/content/carton1.png', '/content/test_images/carton/carton1.png')
shutil.move('/content/carton2.png', '/content/test_images/carton/carton2.png')
shutil.move('/content/carton3.png', '/content/test_images/carton/carton3.png')
shutil.move('/content/carton4.png', '/content/test_images/carton/carton4.png')
shutil.move('/content/carton5.png', '/content/test_images/carton/carton5.png')
shutil.move('/content/carton6.png', '/content/test_images/carton/carton6.png')
shutil.move('/content/carton7.png', '/content/test_images/carton/carton7.png')

shutil.move('/content/metallic1.png', '/content/test_images/metallic/metallic1.png')
shutil.move('/content/metallic2.png', '/content/test_images/metallic/metallic2.png')
shutil.move('/content/metallic3.png', '/content/test_images/metallic/metallic3.png')
shutil.move('/content/metallic4.png', '/content/test_images/metallic/metallic4.png')
shutil.move('/content/metallic5.png', '/content/test_images/metallic/metallic5.png')
shutil.move('/content/metallic6.png', '/content/test_images/metallic/metallic6.png')
shutil.move('/content/metallic7.png', '/content/test_images/metallic/metallic7.png')
# Out:
# '/content/test_images/metallic/metallic7.png'

# %%
os.listdir('/content/images/metallic')
# Out:
# ['metallic54.png',
#  'metallic47.png',
#  'metallic31.png',
#  'metallic20.png',
#  'metallic32.png',
#  'metallic5.jpg',
#  'metallic39.png',
#  'metallic42.png',
#  'metallic25.png',
#  'metallic28.png',
#  'metallic41.png',
#  'metallic55.png',
#  'metallic15.png',
#  'metallic2.jpeg',
#  'metallic40.png',
#  'metallic10.png',
#  'metallic27.png',
#  'metallic45.png',
#  'metallic18.png',
#  'metallic8.png',
#  'metallic3.png',
#  'metallic30.png',
#  'metallic37.png',
#  'metallic53.png',
#  'metallic21.png',
#  'metallic19.png',
#  'metallic34.png',
#  'metallic26.png',
#  'metallic13.png',
#  'metallic12.png',
#  'metallic4.jpeg',
#  'metallic35.png',
#  'metallic48.png',
#  'metallic46.png',
#  'metallic16.png',
#  'metallic29.png',
#  'metallic2.png',
#  'metallic36.png',
#  'metallic9.png',
#  'metallic51.png',
#  'metallic22.png',
#  'metallic49.png',
#  'metallic14.png',
#  'metallic24.png',
#  'metallic11.png',
#  'metallic52.png',
#  'metallic38.png',
# ...

# %%
os.listdir('/content/images/plastic')
# Out:
# ['plastic15.png',
#  'plastic50.png',
#  'plastic41.png',
#  'plastic7.png',
#  'plastic11.png',
#  'plastic25.png',
#  'plastic40.png',
#  'plastic6.png',
#  'plastic44.png',
#  'plastic21.png',
#  'plastic45.png',
#  'plastic28.png',
#  'plastic27.png',
#  'plastic43.png',
#  'plastic47.png',
#  'plastic51.png',
#  'plastic4.jpeg',
#  'plastic34.png',
#  'plastic3.jpeg',
#  'plastic42.png',
#  'Plastic2.jpg',
#  'plastic38.png',
#  'plastic19.png',
#  'plastic33.png',
#  'plastic31.png',
#  'plastic30.png',
#  'plastic5.jpeg',
#  'plastic54.png',
#  'plastic9.png',
#  'plastic52.png',
#  'plastic12.png',
#  'plastic13.png',
#  'plastic53.png',
#  'plastic26.png',
#  'plastic1.png',
#  'plastic20.png',
#  'plastic55.png',
#  'plastic23.png',
#  'plastic8.png',
#  'plastic14.png',
#  'plastic48.png',
#  'plastic17.png',
#  'plastic36.png',
#  'plastic46.png',
#  'plastic29.png',
#  'plastic24.png',
#  'plastic49.png',
#  'plastic35.png',
#  'plastic18.png',
#  'plastic39.png',
# ...

# %%
os.listdir('/content/images/carton')
# Out:
# ['carton11.png',
#  'carton47.png',
#  'carton32.png',
#  'carton41.png',
#  'carton44.png',
#  'carton29.png',
#  'carton21.png',
#  'carton20.png',
#  'carton15.png',
#  'carton3.png',
#  'carton14.png',
#  'carton43.png',
#  'carton7.png',
#  'carton6.png',
#  'carton45.png',
#  'carton42.png',
#  'carton33.png',
#  'carton54.png',
#  'carton5.png',
#  'carton18.png',
#  'carton58.png',
#  'carton27.png',
#  'carton12.png',
#  'carton57.png',
#  'carton1.jpg',
#  'carton24.png',
#  'carton53.png',
#  'carton46.png',
#  'carton56.png',
#  'carton13.png',
#  'carton37.png',
#  'carton26.png',
#  'carton50.png',
#  'carton51.png',
#  'carton9.png',
#  'carton25.png',
#  'carton4.jpeg',
#  'carton31.png',
#  'carton35.png',
#  'carton19.png',
#  'carton60.png',
#  'carton2.jpg',
#  'carton59.png',
#  'carton16.png',
#  'carton23.png',
#  'carton55.png',
#  'carton8.png',
#  'carton22.png',
#  'carton17.png',
#  'carton40.png',
#  'carton36.png',
#  'carton28.png',
#  'carton34.png',
# ...

# %%
os.listdir('/content/images/glass')
# Out:
# ['glass44.png',
#  'glass32.png',
#  'glass4.png',
#  'glass55.png',
#  'glass48.png',
#  'glass7.png',
#  'glass6.png',
#  'glass39.png',
#  'glass22.png',
#  'glass2.jpeg',
#  'glass5.jpg',
#  'glass10.png',
#  'glass46.png',
#  'glass20.png',
#  'glass52.png',
#  'glass23.png',
#  'glass16.png',
#  'glass30.png',
#  'glass15.png',
#  'glass34.png',
#  'glass49.png',
#  'glass37.png',
#  'glass40.png',
#  'glass36.png',
#  'glass14.png',
#  'glass1.jpg',
#  'glass51.png',
#  'glass17.png',
#  'glass50.png',
#  'glass3.png',
#  'glass35.png',
#  'glass27.png',
#  'glass24.png',
#  'glass12.png',
#  'glass41.png',
#  'glass42.png',
#  'glass11.png',
#  'glass56.png',
#  'glass8.png',
#  'glass28.png',
#  'glass31.png',
#  'glass18.png',
#  'glass54.png',
#  'glass47.png',
#  'glass9.png',
#  'glass45.png',
#  'glass26.png',
#  'glass29.png',
#  'glass13.png',
#  'glass33.png',
#  'glass19.png',
#  'glass25.png',
#  'glass21.png',
#  'glass53.png',
#  'glass43.png',
#  'glass38.png']

# %%
os.listdir('/content/test_images/glass')
# Out:
# ['glass1.png',
#  'glass4.png',
#  'glass7.png',
#  'glass6.png',
#  'glass2.png',
#  'glass5.png']

# %%
os.listdir('/content/test_images/carton')
# Out:
# ['carton3.png', 'carton4.png', 'carton7.png', 'carton6.png', 'carton5.png']

# %%
os.listdir('/content/test_images/plastic')
# Out:
# ['plastic7.png', 'plastic5.png', 'plastic6.png', 'plastic4.png']

# %%
os.listdir('/content/test_images/metallic')
# Out:
# ['metallic5.png', 'metallic4.png', 'metallic7.png', 'metallic6.png']

# %% [markdown]
# ## Molde

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# Set up training and testing data generators with augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=30,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    '/content/images/',
    target_size=(224, 224),
    batch_size=8,
    class_mode='categorical'
)

test_generator = test_datagen.flow_from_directory(
    '/content/test_images',
    target_size=(224, 224),
    batch_size=8,
    class_mode='categorical',
    shuffle=False
)

# Load pre-trained MobileNetV2 model
base_model = tf.keras.applications.MobileNetV2(
    input_shape=(224, 224, 3),
    include_top=False,
    weights='imagenet'
)

# Freeze the first 100 layers for fine-tuning
for layer in base_model.layers[:100]:
    layer.trainable = False

# Build the model
x = GlobalAveragePooling2D()(base_model.output)
x = Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
x = Dropout(0.5)(x)
predictions = Dense(4, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)

# Compile the model with a low learning rate
model.compile(optimizer=Adam(learning_rate=1e-5), loss='categorical_crossentropy', metrics=['accuracy'])

# Add callbacks for early stopping and learning rate reduction
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-7)

# Train the model
history = model.fit(
    train_generator,
    validation_data=test_generator,
    epochs=20,
    callbacks=[early_stopping, reduce_lr]
)

# Evaluate the model
loss, accuracy = model.evaluate(test_generator)
print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy:.2%}")

# Save the model in the Keras format
model.save("mobilenet_v2_tuned.keras")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-da75eb610aff> in <cell line: 21>()
#      19 test_datagen = ImageDataGenerator(rescale=1./255)
#      20
# ---> 21 train_generator = train_datagen.flow_from_directory(
#      22     '/content/images/',
#      23     target_size=(224, 224),
#
# /usr/local/lib/python3.10/dist-packages/keras/src/legacy/preprocessing/image.py in flow_from_directory(self, directory, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, follow_links, subset, interpolation, keep_aspect_ratio)
#    1136         keep_aspect_ratio=False,
#    1137     ):
# -> 1138         return DirectoryIterator(
#    1139             directory,
#    1140             self,
#
# ...

# %%
#20 epochs
import numpy as np
from tensorflow.keras.models import load_model
from PIL import Image

# Load the trained model
model = load_model("mobilenet_v2_tuned.keras")

# Function to preprocess the image
def preprocess_image(image_path):
    image = Image.open(image_path).convert('RGB')  # Open the image and ensure it's in RGB mode
    image = image.resize((224, 224))  # Resize the image to the input size of the model
    image_array = np.array(image) / 255.0  # Normalize pixel values to [0, 1]
    return np.expand_dims(image_array, axis=0)  # Add batch dimension

# Path to the image
image_path = "/content/test.png"

# Preprocess the image
processed_image = preprocess_image(image_path)

# Predict the class
predictions = model.predict(processed_image)

# Decode the predictions
class_indices = train_generator.class_indices  # Get the class labels from the training generator
class_labels = {v: k for k, v in class_indices.items()}  # Reverse the dictionary to map indices to labels
predicted_class_index = np.argmax(predictions)  # Get the index of the highest probability
predicted_class_label = class_labels[predicted_class_index]  # Get the corresponding label

print(f"The model predicts the image belongs to the class: {predicted_class_label}")

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-61b26657-6f57-4a2c-b1d6-aa908a6759e1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-61b26657-6f57-4a2c-b1d6-aa908a6759e1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# Set up training and testing data generators with augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=30,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    '/content/images/',
    target_size=(224, 224),
    batch_size=8,
    class_mode='categorical'
)

test_generator = test_datagen.flow_from_directory(
    '/content/test_images',
    target_size=(224, 224),
    batch_size=8,
    class_mode='categorical',
    shuffle=False
)

# Load pre-trained MobileNetV2 model
base_model = tf.keras.applications.MobileNetV2(
    input_shape=(224, 224, 3),
    include_top=False,
    weights='imagenet'
)

# Freeze the first 100 layers for fine-tuning
for layer in base_model.layers[:100]:
    layer.trainable = False

# Build the model
x = GlobalAveragePooling2D()(base_model.output)
x = Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
x = Dropout(0.5)(x)
predictions = Dense(4, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)

# Compile the model with a low learning rate
model.compile(optimizer=Adam(learning_rate=1e-5), loss='categorical_crossentropy', metrics=['accuracy'])

# Add callbacks for early stopping and learning rate reduction
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-7)

# Train the model
history = model.fit(
    train_generator,
    validation_data=test_generator,
    epochs=30,
    callbacks=[early_stopping, reduce_lr]
)

# Evaluate the model
loss, accuracy = model.evaluate(test_generator)
print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy:.2%}")

# Save the model in the Keras format
model.save("mobilenet_v2_tuned.keras")
# Out:
# Found 226 images belonging to 4 classes.
# Found 19 images belonging to 4 classes.
# Epoch 1/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 35s 702ms/step - accuracy: 0.2724 - loss: 4.1424 - val_accuracy: 0.2632 - val_loss: 4.1085 - learning_rate: 1.0000e-05
# Epoch 2/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 38s 577ms/step - accuracy: 0.2677 - loss: 4.0268 - val_accuracy: 0.2105 - val_loss: 3.9591 - learning_rate: 1.0000e-05
# Epoch 3/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 18s 576ms/step - accuracy: 0.3314 - loss: 3.7941 - val_accuracy: 0.2632 - val_loss: 3.8633 - learning_rate: 1.0000e-05
# Epoch 4/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 21s 619ms/step - accuracy: 0.2773 - loss: 3.9854 - val_accuracy: 0.2632 - val_loss: 3.7800 - learning_rate: 1.0000e-05
# Epoch 5/30
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 20s 580ms/step - accuracy: 0.3864 - loss: 3.6991 - val_accuracy: 0.3158 - val_loss: 3.7239 - learning_rate: 1.0000e-05
# Epoch 6/30
# ...

# %%
#30 epochs
import numpy as np
from tensorflow.keras.models import load_model
from PIL import Image

# Load the trained model
model = load_model("mobilenet_v2_tuned.keras")

# Function to preprocess the image
def preprocess_image(image_path):
    image = Image.open(image_path).convert('RGB')  # Open the image and ensure it's in RGB mode
    image = image.resize((224, 224))  # Resize the image to the input size of the model
    image_array = np.array(image) / 255.0  # Normalize pixel values to [0, 1]
    return np.expand_dims(image_array, axis=0)  # Add batch dimension

# Path to the image
image_path = "/content/test.png"

# Preprocess the image
processed_image = preprocess_image(image_path)

# Predict the class
predictions = model.predict(processed_image)

# Decode the predictions
class_indices = train_generator.class_indices  # Get the class labels from the training generator
class_labels = {v: k for k, v in class_indices.items()}  # Reverse the dictionary to map indices to labels
predicted_class_index = np.argmax(predictions)  # Get the index of the highest probability
predicted_class_label = class_labels[predicted_class_index]  # Get the corresponding label

print(f"The model predicts the image belongs to the class: {predicted_class_label}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# The model predicts the image belongs to the class: carton

# %%
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Dropout, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau

# Set up training and testing data generators with augmentation
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=30,
    width_shift_range=0.2,
    height_shift_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest'
)

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    '/content/images/',
    target_size=(224, 224),
    batch_size=8,
    class_mode='categorical'
)

test_generator = test_datagen.flow_from_directory(
    '/content/test_images',
    target_size=(224, 224),
    batch_size=8,
    class_mode='categorical',
    shuffle=False
)

# Load pre-trained MobileNetV2 model
base_model = tf.keras.applications.MobileNetV2(
    input_shape=(224, 224, 3),
    include_top=False,
    weights='imagenet'
)

# Freeze the first 100 layers for fine-tuning
for layer in base_model.layers[:100]:
    layer.trainable = False

# Build the model
x = GlobalAveragePooling2D()(base_model.output)
x = Dense(128, activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
x = Dropout(0.5)(x)
predictions = Dense(4, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)

# Compile the model with a low learning rate
model.compile(optimizer=Adam(learning_rate=1e-5), loss='categorical_crossentropy', metrics=['accuracy'])

# Add callbacks for early stopping and learning rate reduction
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=3, min_lr=1e-7)

# Train the model
history = model.fit(
    train_generator,
    validation_data=test_generator,
    epochs=27,
    callbacks=[early_stopping, reduce_lr]
)

# Evaluate the model
loss, accuracy = model.evaluate(test_generator)
print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy:.2%}")

# Save the model in the Keras format
model.save("mobilenet_v2_tuned.keras")

# %%
#27 epochs
import numpy as np
from tensorflow.keras.models import load_model
from PIL import Image

# Load the trained model
model = load_model("mobilenet_v2_tuned.keras")

# Function to preprocess the image
def preprocess_image(image_path):
    image = Image.open(image_path).convert('RGB')  # Open the image and ensure it's in RGB mode
    image = image.resize((224, 224))  # Resize the image to the input size of the model
    image_array = np.array(image) / 255.0  # Normalize pixel values to [0, 1]
    return np.expand_dims(image_array, axis=0)  # Add batch dimension

# Path to the image
image_path = "/content/test.png"

# Preprocess the image
processed_image = preprocess_image(image_path)

# Predict the class
predictions = model.predict(processed_image)

# Decode the predictions
class_indices = train_generator.class_indices  # Get the class labels from the training generator
class_labels = {v: k for k, v in class_indices.items()}  # Reverse the dictionary to map indices to labels
predicted_class_index = np.argmax(predictions)  # Get the index of the highest probability
predicted_class_label = class_labels[predicted_class_index]  # Get the corresponding label

print(f"The model predicts the image belongs to the class: {predicted_class_label}")
